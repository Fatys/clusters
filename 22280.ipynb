# %% [markdown]
# # Cluster (22280) 1985 CD2
# Hills radius ~ 4997 km
# Escape velocity ~ 10.4 m/s
# H ~ 14.0 mag
#
# Secondaries
# (324154) d_mean ~ 14.70 m/s ; H ~ 16.4 mag
# (459310) d_mean ~ 13.02 m/s ; H ~ 16.9 mag
# 2007BJ41 d_mean ~ 34.65 m/s ; H ~ 17.2 mag

# %%
# Load source file and data
from source import *
a324154 = load_outs('324154_f_combined.outs')
a459310 = load_outs('459310_f_combined.outs')
a2007BJ41 = load_outs('2007BJ41_f_combined.outs')
data = [a324154, a459310, a2007BJ41]

# %%
## Set the limits
max_distance = 20000  # in km
max_velocity = 15.  # m/s

# Plot data
histogram_multi(data=data, d_max=max_distance, v_max=max_velocity)

# %%
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
