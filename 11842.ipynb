# %% [markdown]
# # Cluster (11842) Kap'bos
# Hills radius ~ 1859 km
# Escape velocity ~ 5.2 m/s
# H ~ 13.9 mag
#
# Secondaries
# (228747) d_mean ~ 1.15 m/s ; H ~ 16.6 mag
# (436415) d_mean ~ 0.49 m/s ; H ~ 18.2 mag

# %%
# Load source file and data
from source import *
a228747 = load_outs('228747_f_combined.outs')
a436415 = load_outs('436415_f_combined.outs')

# %%
## Set the limits
max_distance = 10000  # in km
max_velocity = 2.  # m/s

# Plot
histogram(data=a228747, d_max=max_distance, v_max=max_velocity, c='b')
# Out:
# (3626 points plotted)

# %%
## Set the limits
max_distance = 10000  # in km
max_velocity = 10.  # m/s

# Plot
histogram(data=a436415, d_max=max_distance, v_max=max_velocity, c='g')
# Out:
# (241652 points plotted)

# %%
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
pass
